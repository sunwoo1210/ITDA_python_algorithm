# %%
#실습 1-7
#1부터 n까지 정수의 합 구하기 1 (while 문)

print('1부터 n까지 정수의 합을 구합니다.')
n = int(input('n값을 입력하세요.: '))

sum = 0
i = 1

while i <= n:  #i가 n보다 작거나 같은 동안 반복
    sum += i  #sum에 i를 더함
    i += 1  #i에 1을 더함
    
print(f'1부터 {n}까지 정수의 합은 {sum}입니다.')
# Out:
# 1부터 n까지 정수의 합을 구합니다.
# n값을 입력하세요.: 5
# 1부터 5까지 정수의 합은 15입니다.

# %% [markdown]
# <while 문 반복>
# - 반복 구조
# - 사전 판단 반복 구조 <br>
# : 실행하기 전에 반복을 계속 할 것인지를 판단하는 구조
# - 루프 본문 <br>
# : 반복 대상이 되는 명령문 (while 조건식: 명령문 중)
# - 카운터용 변수 <br>
# : 반복을 제어할 때 사용하는 i

# %%
#실습 1-8
#1부터 n까지 정수의 합 구하기 2 (for 문)

print('1부터 n까지 정수의 합을 구합니다.')
n = int(input('n의 값을 입력하세요.: '))

sum = 0
for i in range(1, n+1):
    sum += i  #sum에 i를 더함
    
print(f'1부터 {n}까지 정수의 합은 {sum}입니다.')
# Out:
# 1부터 n까지 정수의 합을 구합니다.
# n의 값을 입력하세요.: 5
# 1부터 5까지 정수의 합은 15입니다.

# %%
#실습 1-9
#a부터 b까지 정수의 합 구하기 (for 문)

print('a부터 b까지 정수의 합을 구합니다.')
a = int(input('정수 a를 입력하세요.: '))
b = int(input('정수 b를 입력하세요.: '))

if a > b:
    a, b = b, a  #a와 b를 오름차순으로 정렬
    
sum = 0
for i in range(a, b + 1):
    sum += i  #sum에 i를 더함
    
print(f'{a}부터 {b}까지 정수의 합은 {sum}입니다.')
# Out:
# a부터 b까지 정수의 합을 구합니다.
# 정수 a를 입력하세요.: 3
# 정수 b를 입력하세요.: 8
# 3부터 8까지 정수의 합은 33입니다.

# %%
#실습 1-9
#a부터 b까지 정수의 합 구하기 (for 문)

print('a부터 b까지 정수의 합을 구합니다.')
a = int(input('정수 a를 입력하세요.: '))
b = int(input('정수 b를 입력하세요.: '))

if a > b:
    a, b = b, a  #a와 b를 오름차순으로 정렬
    
sum = 0
for i in range(a, b + 1):
    sum += i  #sum에 i를 더함
    
print(f'{a}부터 {b}까지 정수의 합은 {sum}입니다.')
# Out:
# a부터 b까지 정수의 합을 구합니다.
# 정수 a를 입력하세요.: 8
# 정수 b를 입력하세요.: 3
# 3부터 8까지 정수의 합은 33입니다.

# %%
#실습 1-10
#a부터 b까지 정수의 합 구하기 1

print('a부터 b까지 정수의 합을 구합니다.')
a = int(input('정수 a를 입력하세요.: '))
b = int(input('정수 b를 입력하세요.: '))

if a > b:
    a, b = b, a
    
sum = 0
for i in range(a, b + 1):
    if i < b:
        print(f'{i} + ', end='')
    else:
        print(f'{i} = ', end='')
    sum += i
    
print(sum)
# Out:
# a부터 b까지 정수의 합을 구합니다.
# 정수 a를 입력하세요.: 3
# 정수 b를 입력하세요.: 3
# 3 = 3

# %%
#실습 1-11
#a부터 b까지 정수의 합 구하기 2

print('a부터 b까지 정수의 합을 구합니다.')
a = int(input('정수 a를 입력하세요.: '))
b = int(input('정수 b를 입력하세요.: '))

if a > b:
    a, b = b, a
    
sum = 0
for i in range(a, b):
    print(f'{i} + ', end = '')
    sum += i
    
print(f'{b} = ', end = '')
sum += b

print(sum)
# Out:
# a부터 b까지 정수의 합을 구합니다.
# 정수 a를 입력하세요.: 2
# 정수 b를 입력하세요.: 9
# 2 + 3 + 4 + 5 + 6 + 7 + 8 + 9 = 44

# %%
#실습 1-12
#+와 -를 번갈아 출력하기 1

print('+와 -를 번갈아 출력합니다.')
n = int(input('몇 개를 출력할까요?: '))

for i in range(n): 
    if i % 2:
        print('-', end = '')
    else:
        print('+', end = '') 
        
print()
# Out:
# +와 -를 번갈아 출력합니다.
# 몇 개를 출력할까요?: 5
# +-+-+

# %%
#실습 1-13
#+와 -를 번갈아 출력하기 2

print('+와 -를 번갈아 출력합니다.')
n = int(input('몇 개를 출력할까요?: '))

for _ in range(n // 2): 
    print('+-', end = '') 

if n % 2:
    print('+', end = '') 
    
print()
# Out:
# +와 -를 번갈아 출력합니다.
# 몇 개를 출력할까요?: 12
# +-+-+-+-+-+-

# %%
#실습 1-14
#*를 n개 출력하되 w개마다 줄바꿈하기 1

print('*를 출력합니다.')
n = int(input('몇 개를 출력할까요?: '))
w = int(input('몇 개마다 줄바꿈할까요?: '))

for i in range(n):
    print('*', end = '')
    if i % w == w - 1:
        print() 

if n % w:
    print()
# Out:
# *를 출력합니다.
# 몇 개를 출력할까요?: 18
# 몇 개마다 줄바꿈할까요?: 6
# ******
# ******
# ******

# %%
#실습 1-15
#*를 n개 출력하되 w개마다 줄바꿈하기 2

print('*를 출력합니다.')
n = int(input('몇 개를 출력할까요?: '))
w = int(input('몇 개마다 줄바꿈할까요?: '))

for _ in range(n // w):
    print('*' * w)

rest = n % w
if rest:
    print('*' * rest)
# Out:
# *를 출력합니다.
# 몇 개를 출력할까요?: 18
# 몇 개마다 줄바꿈할까요?: 3
# ***
# ***
# ***
# ***
# ***
# ***

# %%
#실습 1-16
#1부터 n까지 정수의 합 구하기 (n값은 양수만 입력 받음)

print('1부터 n까지 정수의 합을 구합니다.')

while True:
    n = int(input('n값을 입력하세요.: '))
    if n > 0:
        break 

sum = 0
i = 1

for i in range(1, n+1):
    sum += i
    i += 1
    
print(f'1부터 {n}까지 정수의 합은 {sum}입니다.')
# Out:
# 1부터 n까지 정수의 합을 구합니다.
# n값을 입력하세요.: -6
# n값을 입력하세요.: 0
# n값을 입력하세요.: 10
# 1부터 10까지 정수의 합은 55입니다.

# %%
#실습 1-17
#가로, 세로 길이가 정수이고 넓이가 area인 직사각형에서 변의 길이 나열하기

area = int(input('직사각형의 넓이를 입력하세요.: '))

for i in range(1, area+1):
    if i * i > area: 
        break
    if area % i:
        continue
    print(f'{i} x {area // i}')
# Out:
# 직사각형의 넓이를 입력하세요.: 32
# 1 x 32
# 2 x 16
# 4 x 8

# %%
#실습 1-18
#10~99 사이의 난수 n개 생성하기 (13이 나오면 중단)

import random

n = int(input('난수의 개수를 입력하세요.: '))

for _ in range(n): 
    r = random.randint(10, 99)
    print(r, end = '')
    if r == 13:
        print('\n프로그램을 중단합니다.')
        break
    else:
        print('\n난수 생성을 종료합니다.')
# Out:
# 난수의 개수를 입력하세요.: 5
# 29
# 난수 생성을 종료합니다.
# 35
# 난수 생성을 종료합니다.
# 29
# 난수 생성을 종료합니다.
# 95
# 난수 생성을 종료합니다.
# 47
# 난수 생성을 종료합니다.

# %%
#실습 1-19
#1~12까지 8을 건너뛰고 출력하기 1

for i in range(1, 13):
    if i == 8:
        continue
    print(i, end = '')
    
print()
# Out:
# 12345679101112

# %%
#실습 1-20
#1부터 12까지 8을 건너뛰고 출력하기 2

for i in list(range(1, 8)) + list(range(9, 13)):
    print(i, end = '')
    
print()
# Out:
# 12345679101112

# %%
#실습 1C-3
#2자리 양수(10~99) 입력 받기

print('2자리 양수를 입력하세요.')

while True:
    no = int(input('값을 입력하세요.: '))
    if no >= 10 and no <= 99:
        break

print(f'입력받은 양수는 {no}입니다.')
# Out:
# 2자리 양수를 입력하세요.
# 값을 입력하세요.: 9
# 값을 입력하세요.: 146
# 값을 입력하세요.: 57
# 입력받은 양수는 57입니다.

# %%
#실습 1-21
#구구단 곱셈표 출력하기

print('-'*27)
for i in range(1, 10):
    for j in range(1, 10):
        print(f'{i * j:3}', end = '')
    print()
print('-'*27)
# Out:
# ---------------------------
#   1  2  3  4  5  6  7  8  9
#   2  4  6  8 10 12 14 16 18
#   3  6  9 12 15 18 21 24 27
#   4  8 12 16 20 24 28 32 36
#   5 10 15 20 25 30 35 40 45
#   6 12 18 24 30 36 42 48 54
#   7 14 21 28 35 42 49 56 63
#   8 16 24 32 40 48 56 64 72
#   9 18 27 36 45 54 63 72 81
# ---------------------------

# %%
#실습 1-22
#왼쪽 아래가 직각인 이등변 삼각형으로 * 출력하기

print('왼쪽 아래가 직각인 이등변 삼각형을 출력합니다.')
n = int(input('짧은 변의 길이를 입력하세요.: '))

for i in range(n):
    for j in range(i+1):
        print('*', end = '')
    print()
# Out:
# 왼쪽 아래가 직각인 이등변 삼각형을 출력합니다.
# 짧은 변의 길이를 입력하세요.: 5
# *
# **
# ***
# ****
# *****

# %%
#실습 1-23
#오른쪽 아래가 직각인 이등변 삼각형으로 * 출력하기

print('왼쪽 아래가 직각인 이등변 삼각형을 출력합니다.')
n = int(input('짧은 변의 길이를 입력하세요.: '))

for i in range(n):
    for _ in range(n-i-1):
        print(' ', end = '')
    for _ in range(i+1):
        print('*', end = '')
    print()
# Out:
# 왼쪽 아래가 직각인 이등변 삼각형을 출력합니다.
# 짧은 변의 길이를 입력하세요.: 5
#     *
#    **
#   ***
#  ****
# *****

# %%
#실습 1C-4
#함수 내부, 외부에서 정의한 변수와 객체의 식별 번호를 출력하기

n = 1 
def put_id():
    x = 1 
    print(f'id(x) = {id(x)}')
    
print(f'id(1) = {id(1)}')
print(f'id(n) = {id(n)}')
put_id()
# Out:
# id(1) = 140737069066032
# id(n) = 140737069066032
# id(x) = 140737069066032

# %%
#실습 1C-5
#1부터 100까지 반복하여 출력하기

for i in range(1, 101):
    print(f'i = {i:3}  id(i) = {id(i)}')
# Out:
# i =   1  id(i) = 140737069066032
# i =   2  id(i) = 140737069066064
# i =   3  id(i) = 140737069066096
# i =   4  id(i) = 140737069066128
# i =   5  id(i) = 140737069066160
# i =   6  id(i) = 140737069066192
# i =   7  id(i) = 140737069066224
# i =   8  id(i) = 140737069066256
# i =   9  id(i) = 140737069066288
# i =  10  id(i) = 140737069066320
# i =  11  id(i) = 140737069066352
# i =  12  id(i) = 140737069066384
# i =  13  id(i) = 140737069066416
# i =  14  id(i) = 140737069066448
# i =  15  id(i) = 140737069066480
# i =  16  id(i) = 140737069066512
# i =  17  id(i) = 140737069066544
# i =  18  id(i) = 140737069066576
# i =  19  id(i) = 140737069066608
# i =  20  id(i) = 140737069066640
# i =  21  id(i) = 140737069066672
# i =  22  id(i) = 140737069066704
# i =  23  id(i) = 140737069066736
# i =  24  id(i) = 140737069066768
# i =  25  id(i) = 140737069066800
# i =  26  id(i) = 140737069066832
# i =  27  id(i) = 140737069066864
# i =  28  id(i) = 140737069066896
# i =  29  id(i) = 140737069066928
# i =  30  id(i) = 140737069066960
# i =  31  id(i) = 140737069066992
# i =  32  id(i) = 140737069067024
# i =  33  id(i) = 140737069067056
# i =  34  id(i) = 140737069067088
# i =  35  id(i) = 140737069067120
# i =  36  id(i) = 140737069067152
# i =  37  id(i) = 140737069067184
# i =  38  id(i) = 140737069067216
# i =  39  id(i) = 140737069067248
# i =  40  id(i) = 140737069067280
# i =  41  id(i) = 140737069067312
# i =  42  id(i) = 140737069067344
# i =  43  id(i) = 140737069067376
# i =  44  id(i) = 140737069067408
# i =  45  id(i) = 140737069067440
# i =  46  id(i) = 140737069067472
# i =  47  id(i) = 140737069067504
# i =  48  id(i) = 140737069067536
# i =  49  id(i) = 140737069067568
# i =  50  id(i) = 140737069067600
# i =  51  id(i) = 140737069067632
# i =  52  id(i) = 140737069067664
# i =  53  id(i) = 140737069067696
# i =  54  id(i) = 140737069067728
# i =  55  id(i) = 140737069067760
# i =  56  id(i) = 140737069067792
# i =  57  id(i) = 140737069067824
# i =  58  id(i) = 140737069067856
# i =  59  id(i) = 140737069067888
# i =  60  id(i) = 140737069067920
# i =  61  id(i) = 140737069067952
# i =  62  id(i) = 140737069067984
# i =  63  id(i) = 140737069068016
# i =  64  id(i) = 140737069068048
# i =  65  id(i) = 140737069068080
# i =  66  id(i) = 140737069068112
# i =  67  id(i) = 140737069068144
# i =  68  id(i) = 140737069068176
# i =  69  id(i) = 140737069068208
# i =  70  id(i) = 140737069068240
# i =  71  id(i) = 140737069068272
# i =  72  id(i) = 140737069068304
# i =  73  id(i) = 140737069068336
# i =  74  id(i) = 140737069068368
# i =  75  id(i) = 140737069068400
# i =  76  id(i) = 140737069068432
# i =  77  id(i) = 140737069068464
# i =  78  id(i) = 140737069068496
# i =  79  id(i) = 140737069068528
# i =  80  id(i) = 140737069068560
# i =  81  id(i) = 140737069068592
# i =  82  id(i) = 140737069068624
# i =  83  id(i) = 140737069068656
# i =  84  id(i) = 140737069068688
# i =  85  id(i) = 140737069068720
# i =  86  id(i) = 140737069068752
# i =  87  id(i) = 140737069068784
# i =  88  id(i) = 140737069068816
# i =  89  id(i) = 140737069068848
# i =  90  id(i) = 140737069068880
# i =  91  id(i) = 140737069068912
# i =  92  id(i) = 140737069068944
# i =  93  id(i) = 140737069068976
# i =  94  id(i) = 140737069069008
# i =  95  id(i) = 140737069069040
# i =  96  id(i) = 140737069069072
# i =  97  id(i) = 140737069069104
# i =  98  id(i) = 140737069069136
# i =  99  id(i) = 140737069069168
# i = 100  id(i) = 140737069069200
